# %% [markdown]
# # Rayyan Minhaj (20K-0143 | BCS-8B)
# #Lab 4 Tasks
# ## Q2 - MNIST Classification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras import layers, models
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import plot_model
import matplotlib.pyplot as plt

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images, test_images = train_images / 255.0, test_images / 255.0

# Flatten the images
train_images = train_images.reshape((-1, 28*28))
test_images = test_images.reshape((-1, 28*28))

# %%
model = Sequential()
model.add(layers.Input(shape=(28*28,)))
model.add(Dense(5, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')
model.summary()

# # Plot the model
plot_model(model, to_file='model.png')
# # Display the image
data = plt.imread('model.png')
plt.imshow(data)
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 5)                 3925
#
#  dense_19 (Dense)            (None, 5)                 30
#
#  dense_20 (Dense)            (None, 5)                 30
#
#  dense_21 (Dense)            (None, 5)                 30
#
#  dense_22 (Dense)            (None, 5)                 30
#
#  dense_23 (Dense)            (None, 10)                60
#
# =================================================================
# Total params: 4105 (16.04 KB)
# Trainable params: 4105 (16.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 1.7159 - accuracy: 0.3557 - val_loss: 1.3084 - val_accuracy: 0.5185
# Epoch 2/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 1.0934 - accuracy: 0.5929 - val_loss: 0.9581 - val_accuracy: 0.6428
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.9377 - accuracy: 0.6633 - val_loss: 0.8558 - val_accuracy: 0.7001
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.8689 - accuracy: 0.6914 - val_loss: 0.8222 - val_accuracy: 0.7074
# Epoch 5/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.8234 - accuracy: 0.7093 - val_loss: 0.7840 - val_accuracy: 0.7197

# %%
# Evaluate the model on the test data
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.8000 - accuracy: 0.7199
# [0.7999549508094788, 0.7199000120162964]
